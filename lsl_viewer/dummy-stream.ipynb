# %%
import time
import random
import numpy as np
import threading
from pylsl import StreamInfo, StreamOutlet

# Stream configurations (name, type, sampling rate)
streams_config = [
    ("Stream_250Hz", "EEG", 250),
    ("Stream_500Hz", "EEG", 500),
    ("Stream_1000Hz", "EEG", 1000),
]

MAX_CHANNELS = 25 # Maximum number of channels per stream


def create_lsl_stream(stream_name, stream_type, sampling_rate):
    """Creates and runs an LSL stream with a random number of channels and the specified sampling rate."""
    n_channels = random.randint(1, MAX_CHANNELS)  # Random number of channels (1 to MAX_CHANNELS)
    buffer_size = 12  # Number of samples per push

    # Create LSL stream info and outlet
    info = StreamInfo(stream_name, stream_type, n_channels, sampling_rate, 'float32', stream_name + "_ID")
    outlet = StreamOutlet(info)

    print(f"Started LSL stream: {stream_name} ({sampling_rate} Hz) with {n_channels} channel(s)")

    while True:
        # Generate random data for each channel
        samples = [[random.uniform(-100, 100) for _ in range(n_channels)] for _ in range(buffer_size)]
        timestamps = np.linspace(time.time(), time.time() + (buffer_size / sampling_rate), buffer_size)

        for sample, timestamp in zip(samples, timestamps):
            outlet.push_sample(sample, timestamp)  # Push sample with timestamp

        time.sleep(buffer_size / sampling_rate)  # Maintain correct sampling rate


# Start each stream in a separate thread
threads = []
for stream_name, stream_type, sampling_rate in streams_config:
    thread = threading.Thread(target=create_lsl_stream, args=(stream_name, stream_type, sampling_rate), daemon=True)
    thread.start()
    threads.append(thread)

# Keep the main thread alive
while True:
    time.sleep(1)
# Out:
# 2025-02-05 16:58:15.042 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.042 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.042 (   0.000s) [          CBF3B0]      netinterfaces.cpp:102   INFO| 	IPv4 addr: 7f000001
# 2025-02-05 16:58:15.042 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.042 (   0.000s) [          CBF3B0]      netinterfaces.cpp:105   INFO| 	IPv6 addr: ::1
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::1%lo0
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'gif0' (status: 0, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'stf0' (status: 0, multicast: 0, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'anpi0' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'anpi1' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'en3' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'en4' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'en1' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'en2' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'bridge0' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'ap1' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::4d0:66ac:fd1e:170c%en0
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:102   INFO| 	IPv4 addr: ac120fa5
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'awdl0' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'awdl0' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::50b1:d7ff:feeb:e521%awdl0
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'llw0' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'llw0' (status: 1, multicast: 32768, broadcast: 2)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::50b1:d7ff:feeb:e521%llw0
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'utun0' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'utun0' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::609e:3482:7fe0:8e3e%utun0
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'utun1' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'utun1' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::a008:6bfa:24e8:3bd2%utun1
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'utun2' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.000s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'utun2' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B0]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::59d8:cd3e:ffb:e83d%utun2
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'utun3' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'utun3' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B0]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::ce81:b1c:bd2c:69e%utun3
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'utun4' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'utun4' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B0]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::4921:c103:5d67:162%utun4
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'utun5' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B0]      netinterfaces.cpp:91    INFO| netif 'utun5' (status: 1, multicast: 32768, broadcast: 0)
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B0]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::67ca:eb7c:4f67:55e%utun5
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B0]         api_config.cpp:270   INFO| Loaded default config
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B0]             common.cpp:65    INFO| git:/branch:/build:Release/compiler:Clang-15.0.7/link:SHARED
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B1]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff02:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface ::1 (Can't assign requested address)
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B0]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff02:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface ::1 (Can't assign requested address)
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B2]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff02:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface ::1 (Can't assign requested address)
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B1]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff05:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface ::1 (Can't assign requested address)
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B0]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff05:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface ::1 (Can't assign requested address)
# 2025-02-05 16:58:15.043 (   0.001s) [          CBF3B2]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff05:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface ::1 (Can't assign requested address)
# Started LSL stream: Stream_500Hz (500 Hz) with 22 channel(s)Started LSL stream: Stream_250Hz (250 Hz) with 20 channel(s)
#
# Started LSL stream: Stream_1000Hz (1000 Hz) with 4 channel(s)
